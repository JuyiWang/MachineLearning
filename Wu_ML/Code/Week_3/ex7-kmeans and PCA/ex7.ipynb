# %% [markdown]
# # K-means Clustering and Principal Component Analysis

# %% [markdown]
# ## K-means Clustering

# %%
import numpy as np
import pandas as pd
import scipy.io as scio
import matplotlib.pyplot as plt
import seaborn as sb

# %%
def findClosestCentroids(X,centroids):
    m = X.shape[0]
    k = centroids.shape[0]
    idx = np.zeros(m)

    for i in range(m):
        min_dist = 100000
        for j in range(k):
            dist = np.sum((X[i,:]-centroids[j,:]) ** 2)
            if dist < min_dist:
                min_dist = dist
                idx[i] = j
    # 返回每个x所对应的类序列
    return idx

# %%
data = scio.loadmat('data/ex7data2.mat')
X = data['X']
initital_centroids = np.array([[3, 3], [6, 2], [8, 5]])
idx = findClosestCentroids(X,initital_centroids)
idx[:3]
# Out:
# array([1., 3., 2.])

# %%
data2 = pd.DataFrame(data.get('X'), columns = ['X1', 'X2'])
sb.set(context = 'notebook', style = 'white')
sb.lmplot('X1', 'X2', data = data2, fit_reg = False)
plt.show()

# %%
def computeCentroidMeans(X, idx, k):
    m, n = X.shape
    centroids = np.zeros((k,n))

    for i in range(k):
        indices = np.where(idx == i)
        centroids[i,:] = (np.sum(X[indices,:], axis = 1) / len(indices[0])).ravel()
    return centroids

# %%
computeCentroidMeans(X, idx, 3)
# Out:
# array([[2.42830111, 3.15792418],
#        [5.81350331, 2.63365645],
#        [7.11938687, 3.6166844 ]])

# %%
def run_k_means(X, initial_centroids, max_iters):
    m, n = X.shape
    k = initial_centroids.shape[0]
    idx = np.zeros(m)
    centroids = initial_centroids
    
    for i in range(max_iters):
        idx = findClosestCentroids(X, centroids)
        centroids = computeCentroidMeans(X, idx, k)
    
    return idx, centroids

# %%
idx, centroids = run_k_means(X, initital_centroids, 10)

cluster1 = X[np.where(idx == 0)[0],:]
cluster2 = X[np.where(idx == 1)[0],:]
cluster3 = X[np.where(idx == 2)[0],:]

fig, ax = plt.subplots(figsize=(12,8))
ax.scatter(cluster1[:,0], cluster1[:,1], s=30, color='r', label='Cluster 1')
ax.scatter(cluster2[:,0], cluster2[:,1], s=30, color='g', label='Cluster 2')
ax.scatter(cluster3[:,0], cluster3[:,1], s=30, color='b', label='Cluster 3')
ax.legend()
plt.show()

# %%
def randomInitialCentroids(X, k):
    m, n = X.shape
    centroids = np.zeros((k, n))
    idx = np.random.randint(0, m, k)

    for i in range(k):
        centroids[i,:] = X[idx[i],:]
    return centroids

# %%
from IPython.display import Image
Image(filename = 'data/bird_small.png')

# %%
image_data = scio.loadmat('data/bird_small.mat')
A = image_data['A'] / 255
X = np.reshape(A, (A.shape[0] * A.shape[1], A.shape[2]))
X.shape
# Out:
# (16384, 3)

# %%
# 随机初始化参数
initital_centroids = randomInitialCentroids(X, 16)
# 运行K-means算法
idx, centroids = run_k_means(X, initital_centroids, 10)
# 得到最后一次的中心值
idx = findClosestCentroids(X, centroids)
# 分类像素点
X_recovered = centroids[idx.astype(int),:]
X_recovered = np.reshape(X_recovered, (A.shape[0], A.shape[1], A.shape[2]))
plt.imshow(X_recovered)
plt.show()

# %% [markdown]
# ## Principal Component Analysis

# %%
data = scio.loadmat('data/ex7data1.mat')

X = data['X']

fig, ax = plt.subplots(figsize=(12,8))
ax.scatter(X[:, 0], X[:, 1])
plt.show()

# %%
def pca(X):
    # normalize
    X = (X - X.mean()) / X.std()

    # 计算covariance matirx
    X = np.matrix(X)
    covariance = (X.T * X) / X.shape[0]

    # SVD
    U, S, V = np.linalg.svd(covariance)
    
    return U, S, V

# %%
def reduceData(X, U, k):
    return np.dot(X, U[:,:k])

# %%
U, S, V = pca(X)
Z = reduceData(X, U, 1)
Z
# Out:
# matrix([[-4.74689738],
#         [-7.15889408],
#         [-4.79563345],
#         [-4.45754509],
#         [-4.80263579],
#         [-7.04081342],
#         [-4.97025076],
#         [-8.75934561],
#         [-6.2232703 ],
#         [-7.04497331],
#         [-6.91702866],
#         [-6.79543508],
#         [-6.3438312 ],
#         [-6.99891495],
#         [-4.54558119],
#         [-8.31574426],
#         [-7.16920841],
#         [-5.08083842],
#         [-8.54077427],
#         [-6.94102769],
#         [-8.5978815 ],
#         [-5.76620067],
#         [-8.2020797 ],
#         [-6.23890078],
#         [-4.37943868],
#         [-5.56947441],
#         [-7.53865023],
#         [-7.70645413],
#         [-5.17158343],
#         [-6.19268884],
#         [-6.24385246],
#         [-8.02715303],
#         [-4.81235176],
#         [-7.07993347],
#         [-5.45953289],
#         [-7.60014707],
#         [-4.39612191],
#         [-7.82288033],
#         [-3.40498213],
#         [-6.54290343],
# ...

# %%
def recoverData(Z, U, k):
    return np.dot(Z, U[:,:k].T)

# %%
X_recovered = recoverData(Z, U, 1)
# Out:
# matrix([[3.76152442, 2.89550838],
#         [5.67283275, 4.36677606],
#         [3.80014373, 2.92523637],
#         [3.53223661, 2.71900952],
#         [3.80569251, 2.92950765],
#         [5.57926356, 4.29474931],
#         [3.93851354, 3.03174929],
#         [6.94105849, 5.3430181 ],
#         [4.93142811, 3.79606507],
#         [5.58255993, 4.29728676],
#         [5.48117436, 4.21924319],
#         [5.38482148, 4.14507365],
#         [5.02696267, 3.8696047 ],
#         [5.54606249, 4.26919213],
#         [3.60199795, 2.77270971],
#         [6.58954104, 5.07243054],
#         [5.681006  , 4.37306758],
#         [4.02614513, 3.09920545],
#         [6.76785875, 5.20969415],
#         [5.50019161, 4.2338821 ],
#         [6.81311151, 5.24452836],
#         [4.56923815, 3.51726213],
#         [6.49947125, 5.00309752],
#         [4.94381398, 3.80559934],
#         [3.47034372, 2.67136624],
#         [4.41334883, 3.39726321],
#         [5.97375815, 4.59841938],
# ...

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax.scatter(list(X_recovered[:, 0]), list(X_recovered[:, 1]))
plt.show()

# %%
def plot_n_image(X, n):
    """ plot first n images
    n has to be a square number
    """
    pic_size = int(np.sqrt(X.shape[1]))
    grid_size = int(np.sqrt(n))

    first_n_images = X[:n, :]

    fig, ax_array = plt.subplots(nrows=grid_size, ncols=grid_size,
                                    sharey=True, sharex=True, figsize=(8, 8))

    for r in range(grid_size):
        for c in range(grid_size):
            ax_array[r, c].imshow(first_n_images[grid_size * r + c].reshape((pic_size, pic_size)))
            plt.xticks(np.array([]))
            plt.yticks(np.array([]))

# %%
faces = scio.loadmat('data/ex7faces.mat')
X = faces['X']

# %%
face = np.reshape(X[3,:], (32, 32))
plt.imshow(face)
plt.show()

# %%
U, S, V = pca(X)
Z = reduceData(X, U, 100)

X_recovered = recoverData(Z, U, 100)
face = np.reshape(X_recovered[3,:], (32, 32))
plt.imshow(face)
plt.show()
