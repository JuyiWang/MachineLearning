# %% [markdown]
# # Machine Learning HW.4

# %% [markdown]
# # Recurrent Neural Network

# %% [markdown]
# ## data processing

# %%
import os
import torch
import numpy as np
import pandas as pd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset,DataLoader

# %%
file_path = './ml2020spring-hw4'
data_path = ['training_label.txt', 'training_nolabel.txt', 'testing_data.txt']

# %%
def read_file(path_list):
    data_length = 1
    data = []
    for path in path_list:
        with open(path, 'r',encoding = 'utf-8',newline = '\n',errors = 'ignore') as f:
            for line in f:
                if '_label' in path:
                    text = line.split(' +++$+++ ')[1]
                elif 'test' in path:
                    text = line.split(',')[1]
                else:
                    text = line
                data.append(text)
                data_length += 1
    return data,data_length

# %%
path_list = [os.path.join(file_path,item) for item in data_path]
data,data_length = read_file(path_list)
data_length
# Out:
# 1578616

# %%
def word_to_index(data):
    word2idx = {}
    idx2word = {}
    idx = 1
    for item in data:
        for word in item.replace('\n','').split():
            if word not in word2idx:
                word2idx[word] = idx
                idx2word[idx] = word
                idx += 1
    return word2idx,idx2word,idx

def word_to_vector(path):
    word2vec = {}
    with open(path, 'r', encoding = 'utf-8', errors = 'ignore') as f:
        for line in f:
            tokens = line.split()
            word2vec[tokens[0]] = np.asarray(tokens[1:], dtype = 'float32')
    return word2vec

def seq_to_tokens(text, word2idx, max_len):
    unknown = idx
    text = text.replace('\n','').split()
    sequence = [word2idx[word] if word in word2idx else unknown for word in text]
    sequence = sequence[:max_len]
    x = (np.ones(max_len) * 0).astype('int64')
    x[:len(sequence)] = sequence
    return x

# %%
word2idx, idx2word,idx = word_to_index(data)
assert len(word2idx)+1 == idx

# %%
word2vec = word_to_vector('glove.6B.100d.txt')
len(word2vec)
# Out:
# 400000

# %%
def building_embedding_matrix(path,word2idx,dim):
    word2vec = word_to_vector(path)
    embedding_matrix = np.empty((len(word2idx)+2, dim))
    for word in word2idx:
        if word in word2vec:
            vec = word2vec.get(word)
            if vec is not None:
                embedding_matrix[word2idx.get(word)] = vec
    return embedding_matrix

# %%
embedding_matrix = building_embedding_matrix('glove.6B.100d.txt',word2idx,100)

# %%
embedding_matrix.shape,idx
# Out:
# ((255800, 100), 255799)

# %%
class TextDataSet():

    def __init__(self, path, word2idx, max_len = 128, data_type = 'train'):
        all_data = []
        with open(path, 'r', encoding = 'utf-8', errors = 'ignore') as f:
            for lines in f:
                if data_type == 'train':
                    tokens = lines.replace('\n','').split(' +++$+++ ')
                    label = int(tokens[0])
                else:
                    tokens = lines.replace('\n','').split(',')
                    label = 0
                seq = seq_to_tokens(tokens[1], word2idx, max_len)
                data = {
                    'data':seq,
                    'label':label,
                }
                all_data.append(data)
        self.data = all_data
    
    def __len__(self):
        return len(self.data)

    def __getitem__(self,index):
        return self.data[index]

# %%
text = TextDataSet(path_list[0], word2idx)

# %%
train_loader = DataLoader(text, batch_size = 64, shuffle = True)
type(train_loader)
# Out:
# torch.utils.data.dataloader.DataLoader

# %%
class RNN(nn.Module):
    
    def __init__(self,embed_dim,hidden_size,out_dim,embed_matrix):
        super(RNN,self).__init__()
        self.embedding = nn.Embedding.from_pretrained(torch.tensor(embedding_matrix, dtype = torch.float))
        self.rnn = nn.LSTM(embed_dim, hidden_size, batch_first = True)
        self.func = nn.Sequential(
            nn.Linear(hidden_size,hidden_size*2),
            nn.ReLU(),
            nn.Linear(hidden_size*2,out_dim),
            nn.Dropout() 
        )

    def forward(self,x):
        tokens = self.embedding(x)
        out,(h_t,c_t) = self.rnn(tokens)
        out = self.func(h_t)
        return out.reshape((64,2))

    def squeeze_embedding(self,x,x_len):
        return None

# %%
model = RNN(100,128,2,embedding_matrix)
criditions = nn.CrossEntropyLoss()
optimzer = optim.Adam(model.parameters(), lr = 1e-4)
train_loss = 0
train_acc = 0
for idx,data in enumerate(train_loader):
    model.train()
    pre_out = model(data['data'])
    train_acc += np.sum(np.argmax(pre_out.data.numpy(), axis = 1) == data['label'].numpy()) / 64
    loss = criditions(pre_out,data['label'])
    train_loss += loss.item()
    loss.backward()
    optimzer.step()
    if idx % 100 == 0:
        print('Epoch [%03d : %03d] | Train accuracy is %.5f | Train loss is %.5f' % \
            (idx,int(text.__len__()/100),train_acc,train_loss))
        train_acc, train_loss = 0,0
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-22-497f1a0c9121> in <module>
#       9     train_acc += np.sum(np.argmax(pre_out.data.numpy(), axis = 1) == data['label'].numpy()) / 64
#      10     train_loss += criditions(pre_out,data['label'])
# ---> 11     loss.backward()
#      12     optimzer.step()
#      13     if idx % 100 == 0:
#
# ~/anaconda3/envs/deeplearing/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     105                 products. Defaults to ``False``.
#     106         """
# --> 107         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     108
#     109     def register_hook(self, hook):
#
# ~/anaconda3/envs/deeplearing/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      91     Variable._execution_engine.run_backward(
#      92         tensors, grad_tensors, retain_graph, create_graph,
# ---> 93         allow_unreachable=True)  # allow_unreachable flag
#      94
#      95
#
# RuntimeError: Trying to backward through the graph a second time, but the buffers have already been freed. Specify retain_graph=True when calling backward the first time.
